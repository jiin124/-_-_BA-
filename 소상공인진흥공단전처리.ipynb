# %% [markdown]
# <a href="https://colab.research.google.com/github/jiin124/Goyang_house_price_predict_BAproject/blob/main/%EC%86%8C%EC%83%81%EA%B3%B5%EC%9D%B8%EC%A7%84%ED%9D%A5%EA%B3%B5%EB%8B%A8%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (9,129 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
#한글 폰트 사용을 위해서 세팅
from matplotlib import font_manager,rc

font_path="/content/drive/MyDrive/NanumSquareB.ttf"
font=font_manager.FontProperties(fname=font_path)

# %%
plt.rc('font',family='NanumBarunGothic')

# %%
df=pd.read_csv('/content/경기.csv',encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-3ab7918b4f82> in <module>()
# ----> 1 df=pd.read_csv('/content/경기.csv',encoding='cp949')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.head()
# Out:
#      상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드      상권업종중분류명  \
# 0  20713599    눈높이러닝센타  NaN         R    학문/교육       R13        학문교육기타
# 1  24510829    엠아이케이21  NaN         D       소매       D14     운동/경기용품소매
# 2  20544673  큰손의정부부대찌개  NaN         Q       음식       Q01            한식
# 3  23323139        앞족애  NaN         Q       음식       Q01            한식
# 4  24720922       은호공조  NaN         D       소매       D21  철물/난방/건설자재소매
#
#   상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...        건물관리번호         건물명  \
# 0    R13A01      학습지보급   P85503  ...  4.121010e+24         NaN
# 1    D14A01    운동/경기용품   G47631  ...  4.113510e+24  무지개마을동아아파트
# 2    Q01A07  부대찌개/섞어찌개   I56111  ...  4.157010e+24         NaN
# 3    Q01A01  한식/백반/한정식   I56111  ...  4.115010e+24         NaN
# 4    D21A01      건축백화점   G47519  ...  4.161030e+24       현성아름빌
#
#                     도로명주소     구우편번호    신우편번호  동정보  층정보  호정보          경도  \
# 0         경기도 광명시 오리로 946  423010.0  14221.0  NaN  NaN  NaN  126.858147
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497621 entries, 0 to 497620
# Data columns (total 39 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     497621 non-null  int64
#  1   상호명        497621 non-null  object
#  2   지점명        84558 non-null   object
#  3   상권업종대분류코드  497621 non-null  object
#  4   상권업종대분류명   497621 non-null  object
#  5   상권업종중분류코드  497621 non-null  object
#  6   상권업종중분류명   497621 non-null  object
#  7   상권업종소분류코드  497621 non-null  object
#  8   상권업종소분류명   497621 non-null  object
#  9   표준산업분류코드   465923 non-null  object
#  10  표준산업분류명    465923 non-null  object
#  11  시도코드       497621 non-null  int64
#  12  시도명        497621 non-null  object
#  13  시군구코드      497621 non-null  int64
#  14  시군구명       497621 non-null  object
#  15  행정동코드      497621 non-null  int64
#  16  행정동명       497518 non-null  object
#  17  법정동코드      496741 non-null  float64
#  18  법정동명       496741 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
data=df[['상가업소번호', '상호명', '지점명',  '상권업종대분류명',
       '상권업종중분류명','시도코드','상권업종소분류명', '표준산업분류명',
       '시도명', '시군구코드', '시군구명','행정동명','법정동명','도로명코드', '도로명','도로명주소','경도', '위도']]

# %%
data.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류명', '상권업종중분류코드', '상권업종중분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동명', '법정동명', '도로명코드', '도로명', '도로명주소', '경도',
#        '위도'],
#       dtype='object')

# %%
data.head()
# Out:
#      상가업소번호        상호명  지점명 상권업종대분류명      상권업종중분류명  시도코드   상권업종소분류명  \
# 0  20713599    눈높이러닝센타  NaN    학문/교육        학문교육기타    41      학습지보급
# 1  24510829    엠아이케이21  NaN       소매     운동/경기용품소매    41    운동/경기용품
# 2  20544673  큰손의정부부대찌개  NaN       음식            한식    41  부대찌개/섞어찌개
# 3  23323139        앞족애  NaN       음식            한식    41  한식/백반/한정식
# 4  24720922       은호공조  NaN       소매  철물/난방/건설자재소매    41      건축백화점
#
#                  표준산업분류명  시도명  시군구코드     시군구명  행정동명 법정동명         도로명코드  \
# 0               방문 교육 학원  경기도  41210      광명시  광명3동  광명동  4.121030e+11
# 1          운동 및 경기용품 소매업  경기도  41135  성남시 분당구   구미동  구미동  4.113540e+11
# 2                한식 음식점업  경기도  41570      김포시  김포본동  감정동  4.157030e+11
# 3                한식 음식점업  경기도  41150     의정부시   흥선동  가능동  4.115030e+11
# 4  페인트, 유리 및 기타 건설자재 소매업  경기도  41610      광주시   오포읍  오포읍  4.161040e+11
#
#                     도로명                   도로명주소          경도         위도
# ...

# %%
data['시군구명'].value_counts()
# Out:
# 화성시         29478
# 부천시         26297
# 남양주시        24316
# 평택시         23434
# 파주시         19405
# 성남시 분당구     18703
# 김포시         18183
# 시흥시         17720
# 광주시         16003
# 의정부시        15826
# 안산시 단원구     14221
# 이천시         13210
# 고양시 덕양구     13143
# 용인시 기흥구     12970
# 안양시 동안구     12427
# 수원시 권선구     12042
# 안산시 상록구     11603
# 용인시 처인구     11569
# 수원시 팔달구     11236
# 고양시 일산동구    11192
# 수원시 영통구     11032
# 하남시         10499
# 포천시         10370
# 양주시          9630
# 고양시 일산서구     9410
# 용인시 수지구      9219
# 안양시 만안구      9131
# 광명시          8769
# 오산시          8627
# 성남시 중원구      8620
# 수원시 장안구      8616
# 성남시 수정구      8527
# 안성시          8205
# 구리시          7920
# 군포시          6331
# 양평군          6236
# 여주시          6131
# 가평군          5014
# 동두천시         4478
# 의왕시          3544
# 연천군          2439
# 과천시          1853
# 안산시            17
# 용인시            17
# 수원시             6
# 고양시             2
# Name: 시군구명, dtype: int64

# %%
df=data[data['시군구명'].str.contains('고양시')]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33747 entries, 23 to 497608
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상가업소번호    33747 non-null  int64
#  1   상호명       33747 non-null  object
#  2   지점명       6093 non-null   object
#  3   상권업종대분류명  33747 non-null  object
#  4   상권업종중분류명  33747 non-null  object
#  5   시도코드      33747 non-null  int64
#  6   상권업종소분류명  33747 non-null  object
#  7   표준산업분류명   31537 non-null  object
#  8   시도명       33747 non-null  object
#  9   시군구코드     33747 non-null  int64
#  10  시군구명      33747 non-null  object
#  11  행정동명      33745 non-null  object
#  12  법정동명      33747 non-null  object
#  13  도로명코드     33747 non-null  float64
#  14  도로명       33747 non-null  object
#  15  도로명주소     33747 non-null  object
#  16  경도        33747 non-null  float64
#  17  위도        33747 non-null  float64
# dtypes: float64(3), int64(3), object(12)
# memory usage: 4.9+ MB

# %%
df.to_csv('고양시.csv')

# %%
df['상권업종대분류명'].value_counts()
# Out:
# 음식          10916
# 소매          10705
# 생활서비스        6115
# 학문/교육        3055
# 부동산          1597
# 관광/여가/오락      719
# 스포츠           514
# 숙박            126
# Name: 상권업종대분류명, dtype: int64

# %%
df[df['상권업종대분류명']=='소매']['상권업종중분류명'].value_counts()
# Out:
# 종합소매점            1951
# 의복의류             1391
# 가정/주방/인테리어       1204
# 음/식료품소매           944
# 선물/팬시/기념품         541
# 화장품소매             478
# 사진/광학/정밀기기소매      420
# 운동/경기용품소매         407
# 자동차/자동차용품         390
# 사무/문구/컴퓨터         366
# 가방/신발/액세서리        335
# 가구소매              329
# 철물/난방/건설자재소매      321
# 기타판매업             309
# 건강/미용식품           299
# 의약/의료품소매          160
# 중고품소매/교환          146
# 애견/애완/동물          144
# 책/서적/도서           140
# 가전제품소매            133
# 시계/귀금속소매           91
# 취미/오락관련소매          68
# 예술품/골동품/수석/분재      51
# 유아용품               50
# 페인트/유리제품소매         36
# 종교용품판매              1
# Name: 상권업종중분류명, dtype: int64

# %%
df[df['상권업종대분류명']=='생활서비스']['상권업종중분류명'].value_counts()
# Out:
# 이/미용/건강       2423
# 자동차/이륜차        777
# 세탁/가사서비스       762
# 광고/인쇄          379
# 사진             312
# 개인/가정용품수리      277
# 주택수리           257
# 기타서비스업         257
# 주유소/충전소        100
# 물품기기대여          92
# 운송/배달/택배        89
# 인력/고용/용역알선      87
# 행사/이벤트          81
# 대중목욕탕/휴게        60
# 장례/묘지           48
# 개인서비스           41
# 대행업             29
# 예식/의례/관혼상제      25
# 법무세무회계          19
# Name: 상권업종중분류명, dtype: int64

# %%
df[df['상권업종대분류명']=='학문/교육']['상권업종중분류명'].value_counts()
# Out:
# 학원기타          603
# 학원-보습교습입시     549
# 학원-음악미술무용     477
# 유아교육          464
# 학원-어학         452
# 학원-예능취미체육     200
# 도서관/독서실       155
# 학문교육기타         68
# 학원-창업취업취미      50
# 학원-자격/국가고시     25
# 학원-컴퓨터         12
# Name: 상권업종중분류명, dtype: int64

# %%
study=df[df['상권업종대분류명']=='학문/교육']
study.to_csv('study.csv')

# %%
data=df[df['상권업종대분류명']=='소매']

# %%
mart=data[data['상권업종중분류명']=='종합소매점']
mart['상권업종소분류명'].value_counts()
# Out:
# 편의점          683
# 수퍼마켓         513
# 종합소매         275
# 시장/종합상가      142
# 잡화점          116
# 할인점          102
# 생활용품판매        76
# 백화점           16
# 아케이드/쇼핑센타     15
# 조합/연금매장        6
# 구판장/직판장        6
# 수입품판매점         1
# Name: 상권업종소분류명, dtype: int64

# %%
bigmart=mart[mart['상권업종소분류명']=='할인점']
bigmart.to_csv('mart.csv')

# %%
df[df['상권업종대분류명']=='음식']['상권업종중분류명'].value_counts()
# Out:
# 한식         3724
# 커피점/카페     1736
# 분식          919
# 유흥주점        827
# 일식/수산물      733
# 닭/오리요리      716
# 패스트푸드       627
# 제과제빵떡케익     525
# 양식          486
# 중식          279
# 별식/퓨전요리     243
# 부페           53
# 기타음식업        34
# 음식배달서비스      14
# Name: 상권업종중분류명, dtype: int64

# %% [markdown]
# # 학원

# %%
study=pd.read_csv('study.csv')
study.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3055 entries, 0 to 3054
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3055 non-null   int64
#  1   상가업소번호      3055 non-null   int64
#  2   상호명         3055 non-null   object
#  3   지점명         335 non-null    object
#  4   상권업종대분류명    3055 non-null   object
#  5   상권업종중분류명    3055 non-null   object
#  6   시도코드        3055 non-null   int64
#  7   상권업종소분류명    3055 non-null   object
#  8   표준산업분류명     3055 non-null   object
#  9   시도명         3055 non-null   object
#  10  시군구코드       3055 non-null   int64
#  11  시군구명        3055 non-null   object
#  12  행정동명        3055 non-null   object
#  13  법정동명        3055 non-null   object
#  14  도로명코드       3055 non-null   float64
#  15  도로명         3055 non-null   object
#  16  도로명주소       3055 non-null   object
#  17  경도          3055 non-null   float64
#  18  위도          3055 non-null   float64
# ...

# %%
study['법정동명'].value_counts()
# Out:
# 일산동     443
# 화정동     259
# 주엽동     250
# 행신동     240
# 마두동     203
# 대화동     161
# 탄현동     150
# 중산동     149
# 장항동     116
# 성사동     112
# 백석동      95
# 풍동       85
# 식사동      82
# 정발산동     65
# 가좌동      62
# 덕이동      61
# 고양동      61
# 토당동      58
# 도내동      52
# 향동동      51
# 동산동      44
# 원흥동      41
# 신원동      37
# 주교동      31
# 삼송동      31
# 관산동      30
# 내유동      22
# 성석동      14
# 지축동      13
# 대자동       7
# 사리현동      6
# 화전동       4
# 벽제동       3
# 대장동       2
# 덕은동       2
# 설문동       2
# 문봉동       2
# 현천동       2
# 지영동       1
# 강매동       1
# 행주내동      1
# 산황동       1
# 법곳동       1
# 오금동       1
# 용두동       1
# Name: 법정동명, dtype: int64

# %%
dict(study['법정동명'].value_counts())
# Out:
# {'가좌동': 62,
#  '강매동': 1,
#  '고양동': 61,
#  '관산동': 30,
#  '내유동': 22,
#  '대자동': 7,
#  '대장동': 2,
#  '대화동': 161,
#  '덕은동': 2,
#  '덕이동': 61,
#  '도내동': 52,
#  '동산동': 44,
#  '마두동': 203,
#  '문봉동': 2,
#  '백석동': 95,
#  '법곳동': 1,
#  '벽제동': 3,
#  '사리현동': 6,
#  '산황동': 1,
#  '삼송동': 31,
#  '설문동': 2,
#  '성사동': 112,
#  '성석동': 14,
#  '식사동': 82,
#  '신원동': 37,
#  '오금동': 1,
#  '용두동': 1,
#  '원흥동': 41,
#  '일산동': 443,
#  '장항동': 116,
#  '정발산동': 65,
#  '주교동': 31,
#  '주엽동': 250,
#  '중산동': 149,
#  '지영동': 1,
#  '지축동': 13,
#  '탄현동': 150,
#  '토당동': 58,
#  '풍동': 85,
#  '행신동': 240,
#  '행주내동': 1,
#  '향동동': 51,
#  '현천동': 2,
#  '화전동': 4,
#  '화정동': 259}

# %% [markdown]
# # 대형마트

# %%
bigmart=pd.read_csv('mart.csv')

# %%
bigmart['법정동명'].value_counts()
# Out:
# 대화동     10
# 장항동      9
# 덕이동      8
# 화정동      7
# 행신동      7
# 식사동      6
# 일산동      5
# 풍동       4
# 백석동      4
# 토당동      4
# 향동동      4
# 도내동      4
# 주엽동      4
# 동산동      3
# 성석동      3
# 마두동      3
# 정발산동     2
# 가좌동      2
# 사리현동     2
# 지축동      2
# 중산동      1
# 문봉동      1
# 탄현동      1
# 삼송동      1
# 성사동      1
# 원당동      1
# 원흥동      1
# 화전동      1
# 내유동      1
# Name: 법정동명, dtype: int64

# %%
dict(bigmart['법정동명'].value_counts())
# Out:
# {'가좌동': 2,
#  '내유동': 1,
#  '대화동': 10,
#  '덕이동': 8,
#  '도내동': 4,
#  '동산동': 3,
#  '마두동': 3,
#  '문봉동': 1,
#  '백석동': 4,
#  '사리현동': 2,
#  '삼송동': 1,
#  '성사동': 1,
#  '성석동': 3,
#  '식사동': 6,
#  '원당동': 1,
#  '원흥동': 1,
#  '일산동': 5,
#  '장항동': 9,
#  '정발산동': 2,
#  '주엽동': 4,
#  '중산동': 1,
#  '지축동': 2,
#  '탄현동': 1,
#  '토당동': 4,
#  '풍동': 4,
#  '행신동': 7,
#  '향동동': 4,
#  '화전동': 1,
#  '화정동': 7}

# %% [markdown]
# # 병원

# %%
ho=pd.read_csv('/content/경기도병원현황.csv',encoding='cp949')
ho
# Out:
#       시군명       사업장명     인허가일자                               소재지도로명주소  \
# 0     가평군   가평산속요양병원  20121008                   경기도 가평군 상면 대보간선로 889
# 1     가평군  가평푸른숲요양병원  20170901                  경기도 가평군 상면 물골길 262-23
# 2     가평군   감인노인전문병원  20080715            경기도 가평군 상면 물골길 262-23 (봉수리)
# 3     가평군     강변요양병원  20200306                  경기도 가평군 가평읍 북한강변로 160
# 4     가평군     국군청평병원  19940523                    경기도 가평군 청평면 경춘로 926
# ...   ...        ...       ...                                    ...
# 1306  화성시     화성유일병원  20190617                 경기도 화성시 남양읍 남양로920번길 6
# 1307  화성시   화성제일요양병원  20140521  경기도 화성시 효행로 990, 2층,3층,5층 (진안동, 비젼월드)
# 1308  화성시     화성한방병원  20191227            경기도 화성시 향남읍 발안양감로 187, 4,5층
# 1309  화성시   화성해인요양병원  20160422                경기도 화성시 매송면 화성로 2407-15
# 1310  화성시      희망찬병원  20080905                경기도 화성시 병점중앙로 174 (진안동)
#
#                                  소재지지번주소  소재지우편번호         위도          경도  \
# ...

# %%
ho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1311 entries, 0 to 1310
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시군명        1311 non-null   object
#  1   사업장명       1311 non-null   object
#  2   인허가일자      1311 non-null   int64
#  3   소재지도로명주소   1003 non-null   object
#  4   소재지지번주소    1013 non-null   object
#  5   소재지우편번호    1004 non-null   float64
#  6   위도         1005 non-null   float64
#  7   경도         1005 non-null   float64
#  8   인허가취소일자    8 non-null      float64
#  9   영업상태명      1311 non-null   object
#  10  폐업일자       425 non-null    float64
#  11  소재지시설전화번호  1270 non-null   object
#  12  소재지면적정보    0 non-null      float64
#  13  업태구분명정보    1311 non-null   object
#  14  X좌표값       1183 non-null   float64
#  15  Y좌표값       1183 non-null   float64
#  16  의료기관종별명    1299 non-null   object
#  17  의료인수       1299 non-null   float64
#  18  입원실수       1299 non-null   float64
# ...

# %%
ho=ho[ho['시군명']=='고양시']
ho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 12 to 118
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   시군명        107 non-null    object
#  1   사업장명       107 non-null    object
#  2   인허가일자      107 non-null    int64
#  3   소재지도로명주소   91 non-null     object
#  4   소재지지번주소    91 non-null     object
#  5   소재지우편번호    91 non-null     float64
#  6   위도         91 non-null     float64
#  7   경도         91 non-null     float64
#  8   인허가취소일자    0 non-null      float64
#  9   영업상태명      107 non-null    object
#  10  폐업일자       34 non-null     float64
#  11  소재지시설전화번호  98 non-null     object
#  12  소재지면적정보    0 non-null      float64
#  13  업태구분명정보    107 non-null    object
#  14  X좌표값       96 non-null     float64
#  15  Y좌표값       96 non-null     float64
#  16  의료기관종별명    107 non-null    object
#  17  의료인수       107 non-null    float64
#  18  입원실수       107 non-null    float64
# ...

# %%
ho.columns
# Out:
# Index(['시군명', '사업장명', '인허가일자', '소재지도로명주소', '소재지지번주소', '소재지우편번호', '위도', '경도',
#        '인허가취소일자', '영업상태명', '폐업일자', '소재지시설전화번호', '소재지면적정보', '업태구분명정보', 'X좌표값',
#        'Y좌표값', '의료기관종별명', '의료인수', '입원실수', '병상수', '총면적', '진료과목내용', '진료과목내용정보',
#        '특수구급차대수', '일반구급차대수', '허가병상수'],
#       dtype='object')

# %%
ho=ho[['시군명', '사업장명', '인허가일자', '소재지도로명주소', '소재지지번주소', '소재지우편번호', '위도', '경도',
       '인허가취소일자', '영업상태명', '폐업일자']]
ho
# Out:
#      시군명      사업장명     인허가일자  \
# 12   고양시   가이드치과병원  20061213
# 13   고양시  강북성심요양병원  20080422
# 14   고양시     건누리병원  20100609
# 15   고양시    고산한방병원  20050725
# 16   고양시    고양성모병원  20111031
# ..   ...       ...       ...
# 114  고양시    햇살요양병원  20070607
# 115  고양시     허유재병원  20040302
# 116  고양시     활기찬병원  20120125
# 117  고양시   효그린요양병원  20080926
# 118  고양시    효림요양병원  20080814
#
#                                               소재지도로명주소  \
# 12                 경기도 고양시 일산동구 숲속마을로 42 3층 (풍동,에이스타워)
# 13                                                 NaN
# 14                                                 NaN
# 15               경기도 고양시 일산서구 중앙로 1455, 901~904호 (주엽동)
# 16       경기도 고양시 덕양구 통일로768번길 18 (관산동, 2층, 3층, 4층, 6층)
# ..                                                 ...
# 114                    경기도 고양시 일산동구 공릉천로33번길 71 (사리현동)
# 115     경기도 고양시 일산동구 중앙로 1317, 지하1층~5층,6층 일부, 8층 (장항동)
# 116                   경기도 고양시 덕양구 화중로 50, 4,5,6층 (화정동)
# ...

# %%
ho=ho[ho['영업상태명']=='영업중']
ho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 13 to 118
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군명       72 non-null     object
#  1   사업장명      72 non-null     object
#  2   인허가일자     72 non-null     int64
#  3   소재지도로명주소  56 non-null     object
#  4   소재지지번주소   56 non-null     object
#  5   소재지우편번호   56 non-null     float64
#  6   위도        56 non-null     float64
#  7   경도        56 non-null     float64
#  8   인허가취소일자   0 non-null      float64
#  9   영업상태명     72 non-null     object
#  10  폐업일자      0 non-null      float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 6.8+ KB

# %%
ho.to_csv('/content/hospital_ori.csv')

# %%
ho.head(4)
# Out:
#    Unnamed: 0  시군명       사업장명     인허가일자                        소재지도로명주소  \
# 0          13  고양시   강북성심요양병원  20080422                             NaN
# 1          14  고양시      건누리병원  20100609                             NaN
# 2          17  고양시  고양센트럴요양병원  20191111                             NaN
# 3          18  고양시     고양정신병원  19990304  경기도 고양시 덕양구 통일로1102번길 46 (내유동)
#
#                                 소재지지번주소  소재지우편번호         위도          경도  \
# 0                                   NaN      NaN        NaN         NaN
# 1                                   NaN      NaN        NaN         NaN
# 2                                   NaN      NaN        NaN         NaN
# 3  경기도 고양시 덕양구 내유동 294번지 2호 294-2,3,4,5  10264.0  37.711499  126.854566
#
#    인허가취소일자 영업상태명  폐업일자
# 0      NaN   영업중   NaN
# 1      NaN   영업중   NaN
# 2      NaN   영업중   NaN
# 3      NaN   영업중   NaN

# %%
h=ho.fillna('N')

# %%
h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  72 non-null     int64
#  1   시군명         72 non-null     object
#  2   사업장명        72 non-null     object
#  3   인허가일자       72 non-null     int64
#  4   소재지도로명주소    72 non-null     object
#  5   소재지지번주소     72 non-null     object
#  6   소재지우편번호     72 non-null     object
#  7   위도          72 non-null     object
#  8   경도          72 non-null     object
#  9   인허가취소일자     72 non-null     object
#  10  영업상태명       72 non-null     object
#  11  폐업일자        72 non-null     object
# dtypes: int64(2), object(10)
# memory usage: 6.9+ KB

# %%
import re

# %%
h.head(3)
# Out:
#    Unnamed: 0  시군명       사업장명     인허가일자 소재지도로명주소 소재지지번주소 소재지우편번호 위도 경도  \
# 0          13  고양시   강북성심요양병원  20080422        N       N       N  N  N
# 1          14  고양시      건누리병원  20100609        N       N       N  N  N
# 2          17  고양시  고양센트럴요양병원  20191111        N       N       N  N  N
#
#   인허가취소일자 영업상태명 폐업일자
# 0       N   영업중    N
# 1       N   영업중    N
# 2       N   영업중    N

# %%
h['행정동명']=h['소재지도로명주소'].str.join('')
h
# Out:
#     Unnamed: 0  시군명       사업장명     인허가일자  \
# 0           13  고양시   강북성심요양병원  20080422
# 1           14  고양시      건누리병원  20100609
# 2           17  고양시  고양센트럴요양병원  20191111
# 3           18  고양시     고양정신병원  19990304
# 4           19  고양시    고양휴메디병원  20200413
# ..         ...  ...        ...       ...
# 67         113  고양시      해븐리병원  20080711
# 68         115  고양시      허유재병원  20040302
# 69         116  고양시      활기찬병원  20120125
# 70         117  고양시    효그린요양병원  20080926
# 71         118  고양시     효림요양병원  20080814
#
#                                              소재지도로명주소  \
# 0                                                   N
# 1                                                   N
# 2                                                   N
# 3                      경기도 고양시 덕양구 통일로1102번길 46 (내유동)
# 4                                                   N
# ..                                                ...
# 67  경기도 고양시 일산동구 중산로 117 (중산동, 성도빌딩,지하1층일부,1층일부,3층...
# ...

# %%
for i in range(len(h)):
  h['행정동명'][i]=re.findall('\((^)+)',h['소재지도로명주소'][i])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-188-d870fb5d0707> in <module>()
#       1 for i in range(len(h)):
# ----> 2   h['행정동명'][i]=re.findall('\((^)+)',h['소재지도로명주소'][i])
#
# /usr/lib/python3.7/re.py in findall(pattern, string, flags)
#     223
#     224     Empty matches are included in the result."""
# --> 225     return _compile(pattern, flags).findall(string)
#     226
#     227 def finditer(pattern, string, flags=0):
#
# /usr/lib/python3.7/re.py in _compile(pattern, flags)
#     286     if not sre_compile.isstring(pattern):
#     287         raise TypeError("first argument must be string or compiled pattern")
# --> 288     p = sre_compile.compile(pattern, flags)
#     289     if not (flags & DEBUG):
#     290         if len(_cache) >= _MAXCACHE:
#
# /usr/lib/python3.7/sre_compile.py in compile(p, flags)
#     762     if isstring(p):
# ...

# %%
h.head()
# Out:
#    Unnamed: 0  시군명       사업장명     인허가일자                        소재지도로명주소  \
# 0          13  고양시   강북성심요양병원  20080422                               N
# 1          14  고양시      건누리병원  20100609                               N
# 2          17  고양시  고양센트럴요양병원  20191111                               N
# 3          18  고양시     고양정신병원  19990304  경기도 고양시 덕양구 통일로1102번길 46 (내유동)
# 4          19  고양시    고양휴메디병원  20200413                               N
#
#                                 소재지지번주소  소재지우편번호         위도          경도  \
# 0                                     N        N          N           N
# 1                                     N        N          N           N
# 2                                     N        N          N           N
# 3  경기도 고양시 덕양구 내유동 294번지 2호 294-2,3,4,5  10264.0  37.711499  126.854566
# 4                                     N        N          N           N
#
#   인허가취소일자 영업상태명 폐업일자   행정동명
# 0       N   영업중    N     []
# 1       N   영업중    N     []
# ...

# %%
h.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  72 non-null     int64
#  1   시군명         72 non-null     object
#  2   사업장명        72 non-null     object
#  3   인허가일자       72 non-null     int64
#  4   소재지도로명주소    72 non-null     object
#  5   소재지지번주소     72 non-null     object
#  6   소재지우편번호     72 non-null     object
#  7   위도          72 non-null     object
#  8   경도          72 non-null     object
#  9   인허가취소일자     72 non-null     object
#  10  영업상태명       72 non-null     object
#  11  폐업일자        72 non-null     object
#  12  행정동명        72 non-null     object
# dtypes: int64(2), object(11)
# memory usage: 7.4+ KB

# %%
h.to_csv('hospital.csv')

# %%
hos=pd.read_csv('hospital.csv',encoding='cp949')
hos
# Out:
#     Unnamed: 0  Unnamed: 0.1  시군명       사업장명     인허가일자  \
# 0            0            13  고양시   강북성심요양병원  20080422
# 1            1            14  고양시      건누리병원  20100609
# 2            2            17  고양시  고양센트럴요양병원  20191111
# 3            3            18  고양시     고양정신병원  19990304
# 4            4            19  고양시    고양휴메디병원  20200413
# ..         ...           ...  ...        ...       ...
# 67          67           113  고양시      해븐리병원  20080711
# 68          68           115  고양시      허유재병원  20040302
# 69          69           116  고양시      활기찬병원  20120125
# 70          70           117  고양시    효그린요양병원  20080926
# 71          71           118  고양시     효림요양병원  20080814
#
#                                              소재지도로명주소  \
# 0                                                   N
# 1                                                   N
# 2                                                   N
# 3                      경기도 고양시 덕양구 통일로1102번길 46 (내유동)
# ...

# %%
hos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    72 non-null     int64
#  1   Unnamed: 0.1  72 non-null     int64
#  2   시군명           72 non-null     object
#  3   사업장명          72 non-null     object
#  4   인허가일자         72 non-null     int64
#  5   소재지도로명주소      72 non-null     object
#  6   소재지지번주소       72 non-null     object
#  7   소재지우편번호       72 non-null     object
#  8   위도            72 non-null     object
#  9   경도            72 non-null     object
#  10  인허가취소일자       72 non-null     object
#  11  영업상태명         72 non-null     object
#  12  폐업일자          72 non-null     object
#  13  행정동명          72 non-null     object
# dtypes: int64(3), object(11)
# memory usage: 8.0+ KB

# %%
import re

# %%
for i in range(len(hos)):
  hos['행정동명'][i]=re.sub("\[|\,|\]","",str(hos['행정동명'][i]))

# %%
for i in range(len(hos)):
  hos['행정동명'][i]=re.sub("\'|\'|\]","",str(hos['행정동명'][i]))

# %%
hos['행정동명'].value_counts()
# Out:
# 중산동                                         6
# 행신동                                         4
# 화정동                                         4
# 장항동                                         3
# 원흥동                                         3
# 대화동                                         3
# 풍동                                          3
# 식사동 동국대학교일산병원                               2
# 백석동                                         2
# 정발산동                                        2
# 토당동                                         2
# 성석동                                         2
# 내유동                                         2
# 주교동                                         2
# 백석동 한국음주문화센터                                1
# 주엽동 2층~5층                                   1
# 마두동 강촌마을6단지아파트                              1
# 장항동 위너스 21-∥3568층                           1
# 일산동 에이스스타디움78층                              1
# 장항동 남정시티프라자8차 3층 4층 6층 8층                   1
# ...

# %%
hos.to_csv('hospital1.csv')

# %%
ho=pd.read_csv('hospital1.csv',encoding='cp949')
ho['행정동명'].value_counts()
# Out:
# 중산동     8
# 화정동     7
# 백석동     7
# 장항동     6
# 주엽동     5
# 마두동     4
# 행신동     4
# 식사동     3
# 대화동     3
# 덕이동     3
# 원흥동     3
# 풍동      3
# 주교동     2
# 성석동     2
# 정발산동    2
# 일산동     2
# 토당동     2
# 내유동     2
# 벽제동     1
# 성사동     1
# 탄현동     1
# 문봉동     1
# Name: 행정동명, dtype: int64

# %%
dict(ho['행정동명'].value_counts())
# Out:
# {'내유동': 2,
#  '대화동': 3,
#  '덕이동': 3,
#  '마두동': 4,
#  '문봉동': 1,
#  '백석동': 7,
#  '벽제동': 1,
#  '성사동': 1,
#  '성석동': 2,
#  '식사동': 3,
#  '원흥동': 3,
#  '일산동': 2,
#  '장항동': 6,
#  '정발산동': 2,
#  '주교동': 2,
#  '주엽동': 5,
#  '중산동': 8,
#  '탄현동': 1,
#  '토당동': 2,
#  '풍동': 3,
#  '행신동': 4,
#  '화정동': 7}

# %% [markdown]
# # 프랜차이즈
#
# - 스타벅스
# - 서브웨이
# - 베스킨라빈스
# - 버거킹

# %%
df=pd.read_csv('/content/고양시.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0    상가업소번호      상호명  지점명 상권업종대분류명   상권업종중분류명  시도코드  상권업종소분류명  \
# 0          23  24290225     오일클럽  NaN       소매  자동차/자동차용품    41   자동차부품판매
# 1          30  20659194  바이오젠코리아  NaN       소매    음/식료품소매    41      식료품점
# 2          38  17175320     진짜곱창  NaN       음식         한식    41  곱창/양구이전문
#
#                  표준산업분류명  시도명  시군구코드      시군구명  행정동명 법정동명         도로명코드  \
# 0  기타 자동차신품 부품 및 내장품 판매업  경기도  41281   고양시 덕양구   능곡동  내곡동  4.128140e+11
# 1             기타 식료품 소매업  경기도  41287  고양시 일산서구   송포동  법곳동  4.128740e+11
# 2                한식 음식점업  경기도  41281   고양시 덕양구  화정1동  화정동  4.128130e+11
#
#                     도로명                        도로명주소          경도         위도
# 0   경기도 고양시 덕양구 내곡길70번길       경기도 고양시 덕양구 내곡길70번길 34  126.808592  37.643442
# 1  경기도 고양시 일산서구 대화로37번길  경기도 고양시 일산서구 대화로37번길 102-18  126.722466  37.667823
# 2       경기도 고양시 덕양구 백양로          경기도 고양시 덕양구 백양로 161  126.835227  37.640059

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '상가업소번호', '상호명', '지점명', '상권업종대분류명', '상권업종중분류명', '시도코드',
#        '상권업종소분류명', '표준산업분류명', '시도명', '시군구코드', '시군구명', '행정동명', '법정동명', '도로명코드',
#        '도로명', '도로명주소', '경도', '위도'],
#       dtype='object')

# %%
food=df[df['상권업종대분류명']=='음식']

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10916 entries, 2 to 33744
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10916 non-null  int64
#  1   상가업소번호      10916 non-null  int64
#  2   상호명         10916 non-null  object
#  3   지점명         3033 non-null   object
#  4   상권업종대분류명    10916 non-null  object
#  5   상권업종중분류명    10916 non-null  object
#  6   시도코드        10916 non-null  int64
#  7   상권업종소분류명    10916 non-null  object
#  8   표준산업분류명     10887 non-null  object
#  9   시도명         10916 non-null  object
#  10  시군구코드       10916 non-null  int64
#  11  시군구명        10916 non-null  object
#  12  행정동명        10915 non-null  object
#  13  법정동명        10916 non-null  object
#  14  도로명코드       10916 non-null  float64
#  15  도로명         10916 non-null  object
#  16  도로명주소       10916 non-null  object
#  17  경도          10916 non-null  float64
#  18  위도          10916 non-null  float64
# ...

# %% [markdown]
# ## 스타벅스

# %%
starbucks=food[food['상호명'].str.contains('스타벅스'or'starbucks'or'Starbucks'or'STARBUCKS')]
starbucks
# Out:
#        Unnamed: 0    상가업소번호          상호명            지점명 상권업종대분류명 상권업종중분류명  \
# 1294        21199  23410915         스타벅스            백석점       음식   커피점/카페
# 2519        39124  23233854         스타벅스           대화역점       음식   커피점/카페
# 3005        46932  25505111         스타벅스           마두역점       음식   커피점/카페
# 3271        51168  25370441         스타벅스          일산백마점       음식   커피점/카페
# 3912        62202  11768198         스타벅스          고양DT점       음식   커피점/카페
# 5091        78086  16768307         스타벅스          고양행신점       음식   커피점/카페
# 5212        79651  19956909         스타벅스            화정점       음식   커피점/카페
# 5375        81616  16602958         스타벅스         소노캄고양점       음식   커피점/카페
# 5481        83007  16608335         스타벅스           삼송역점       음식   커피점/카페
# 5565        83997  16728143         스타벅스           원흥역점       음식   커피점/카페
# 6322        95816  11794632         스타벅스          원당DT점       음식   커피점/카페
# 6766       102756  23403312         스타벅스          일산식사점       음식   일식/수산물
# ...

# %%
starbucks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38 entries, 1294 to 29107
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  38 non-null     int64
#  1   상가업소번호      38 non-null     int64
#  2   상호명         38 non-null     object
#  3   지점명         34 non-null     object
#  4   상권업종대분류명    38 non-null     object
#  5   상권업종중분류명    38 non-null     object
#  6   시도코드        38 non-null     int64
#  7   상권업종소분류명    38 non-null     object
#  8   표준산업분류명     38 non-null     object
#  9   시도명         38 non-null     object
#  10  시군구코드       38 non-null     int64
#  11  시군구명        38 non-null     object
#  12  행정동명        38 non-null     object
#  13  법정동명        38 non-null     object
#  14  도로명코드       38 non-null     float64
#  15  도로명         38 non-null     object
#  16  도로명주소       38 non-null     object
#  17  경도          38 non-null     float64
#  18  위도          38 non-null     float64
# ...

# %%
starbucks.to_csv('starbucks.csv')

# %%
starbucks['법정동명'].value_counts()
# Out:
# 대화동    6
# 주엽동    4
# 백석동    3
# 장항동    3
# 화정동    3
# 풍동     2
# 덕이동    2
# 식사동    2
# 탄현동    2
# 행신동    2
# 원흥동    1
# 삼송동    1
# 중산동    1
# 신원동    1
# 고양동    1
# 동산동    1
# 일산동    1
# 마두동    1
# 주교동    1
# Name: 법정동명, dtype: int64

# %%
dict(starbucks['법정동명'].value_counts())
# Out:
# {'고양동': 1,
#  '대화동': 6,
#  '덕이동': 2,
#  '동산동': 1,
#  '마두동': 1,
#  '백석동': 3,
#  '삼송동': 1,
#  '식사동': 2,
#  '신원동': 1,
#  '원흥동': 1,
#  '일산동': 1,
#  '장항동': 3,
#  '주교동': 1,
#  '주엽동': 4,
#  '중산동': 1,
#  '탄현동': 2,
#  '풍동': 2,
#  '행신동': 2,
#  '화정동': 3}

# %% [markdown]
# ## 베스킨라빈스

# %%
baskin=food[food['상호명'].str.contains(r'(라빈스)')]
baskin
# Out:
#        Unnamed: 0    상가업소번호                 상호명         지점명 상권업종대분류명 상권업종중분류명  \
# 934         14340  25800565            배스킨라빈스31       호수공원점       음식    패스트푸드
# 1232        20178  25621916            배스킨라빈스31       일산중산점       음식    패스트푸드
# 2463        38332  19962470            배스킨라빈스31     일산장항호수점       음식   커피점/카페
# 3099        48422  12423638            배스킨라빈스31       고양능곡점       음식    패스트푸드
# 3159        49212  12421769            배스킨라빈스31     고양신원마을점       음식    패스트푸드
# 3163        49280  12423899            배스킨라빈스31     고양행신햇빛점       음식    패스트푸드
# 3288        51420  12423566  배스킨라빈스31고양터미널홈플러스점  고양터미널홈플러스점       음식    패스트푸드
# 3290        51430  23350961               코알라빈스         NaN       음식       한식
# 3293        51453  12423572            배스킨라빈스31        대화역점       음식    패스트푸드
# 4382        69275  25778876            배스킨라빈스31       일산백석역       음식    패스트푸드
# 4475        70747  25862526            배스킨라빈스31        행신서정       음식    패스트푸드
# ...

# %%
baskin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 934 to 31554
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  40 non-null     int64
#  1   상가업소번호      40 non-null     int64
#  2   상호명         40 non-null     object
#  3   지점명         33 non-null     object
#  4   상권업종대분류명    40 non-null     object
#  5   상권업종중분류명    40 non-null     object
#  6   시도코드        40 non-null     int64
#  7   상권업종소분류명    40 non-null     object
#  8   표준산업분류명     40 non-null     object
#  9   시도명         40 non-null     object
#  10  시군구코드       40 non-null     int64
#  11  시군구명        40 non-null     object
#  12  행정동명        40 non-null     object
#  13  법정동명        40 non-null     object
#  14  도로명코드       40 non-null     float64
#  15  도로명         40 non-null     object
#  16  도로명주소       40 non-null     object
#  17  경도          40 non-null     float64
#  18  위도          40 non-null     float64
# ...

# %%
baskin['법정동명'].value_counts()
# Out:
# 장항동    4
# 행신동    4
# 대화동    4
# 백석동    3
# 일산동    3
# 풍동     2
# 화정동    2
# 가좌동    2
# 중산동    2
# 성사동    2
# 내유동    1
# 원흥동    1
# 탄현동    1
# 관산동    1
# 마두동    1
# 고양동    1
# 삼송동    1
# 동산동    1
# 덕이동    1
# 신원동    1
# 토당동    1
# 향동동    1
# Name: 법정동명, dtype: int64

# %%
dict(baskin['법정동명'].value_counts())
# Out:
# {'가좌동': 2,
#  '고양동': 1,
#  '관산동': 1,
#  '내유동': 1,
#  '대화동': 4,
#  '덕이동': 1,
#  '동산동': 1,
#  '마두동': 1,
#  '백석동': 3,
#  '삼송동': 1,
#  '성사동': 2,
#  '신원동': 1,
#  '원흥동': 1,
#  '일산동': 3,
#  '장항동': 4,
#  '중산동': 2,
#  '탄현동': 1,
#  '토당동': 1,
#  '풍동': 2,
#  '행신동': 4,
#  '향동동': 1,
#  '화정동': 2}

# %%
baskin.to_csv('baskin.csv')

# %% [markdown]
# ## 서브웨이

# %%
subway=food[food['상호명'].str.contains(r'(브웨이)')]
subway

# %%
subway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 1903 to 33347
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  13 non-null     int64
#  1   상가업소번호      13 non-null     int64
#  2   상호명         13 non-null     object
#  3   지점명         13 non-null     object
#  4   상권업종대분류명    13 non-null     object
#  5   상권업종중분류명    13 non-null     object
#  6   시도코드        13 non-null     int64
#  7   상권업종소분류명    13 non-null     object
#  8   표준산업분류명     13 non-null     object
#  9   시도명         13 non-null     object
#  10  시군구코드       13 non-null     int64
#  11  시군구명        13 non-null     object
#  12  행정동명        13 non-null     object
#  13  법정동명        13 non-null     object
#  14  도로명코드       13 non-null     float64
#  15  도로명         13 non-null     object
#  16  도로명주소       13 non-null     object
#  17  경도          13 non-null     float64
#  18  위도          13 non-null     float64
# ...

# %%
subway['법정동명'].value_counts()
# Out:
# 대화동    2
# 일산동    2
# 주엽동    1
# 탄현동    1
# 백석동    1
# 마두동    1
# 신원동    1
# 화정동    1
# 장항동    1
# 원흥동    1
# 식사동    1
# Name: 법정동명, dtype: int64

# %%
dict(subway['법정동명'].value_counts())
# Out:
# {'대화동': 2,
#  '마두동': 1,
#  '백석동': 1,
#  '식사동': 1,
#  '신원동': 1,
#  '원흥동': 1,
#  '일산동': 2,
#  '장항동': 1,
#  '주엽동': 1,
#  '탄현동': 1,
#  '화정동': 1}

# %% [markdown]
# # 편의점

# %%
data=df[df['상권업종대분류명']=='소매']

# %%
mart=data[data['상권업종중분류명']=='종합소매점']
mart['상권업종소분류명'].value_counts()
# Out:
# 편의점          683
# 수퍼마켓         513
# 종합소매         275
# 시장/종합상가      142
# 잡화점          116
# 할인점          102
# 생활용품판매        76
# 백화점           16
# 아케이드/쇼핑센타     15
# 조합/연금매장        6
# 구판장/직판장        6
# 수입품판매점         1
# Name: 상권업종소분류명, dtype: int64

# %%
board=mart[mart['상권업종소분류명']=='편의점']

# %%
board['법정동명'].value_counts()
# Out:
# 대화동     46
# 덕이동     44
# 일산동     39
# 행신동     37
# 장항동     37
# 백석동     30
# 화정동     30
# 탄현동     29
# 식사동     27
# 주엽동     23
# 풍동      23
# 중산동     23
# 마두동     19
# 주교동     17
# 관산동     17
# 삼송동     17
# 고양동     16
# 동산동     16
# 성석동     15
# 도내동     15
# 토당동     14
# 정발산동    14
# 성사동     14
# 내유동     14
# 대자동     13
# 원흥동     13
# 신원동     12
# 문봉동      9
# 가좌동      8
# 벽제동      7
# 향동동      6
# 화전동      4
# 지영동      4
# 지축동      4
# 덕은동      4
# 설문동      4
# 사리현동     3
# 용두동      3
# 법곳동      3
# 내곡동      2
# 구산동      2
# 대장동      2
# 현천동      1
# 강매동      1
# 오금동      1
# 원당동      1
# Name: 법정동명, dtype: int64

# %%
dict(board['법정동명'].value_counts())
# Out:
# {'가좌동': 8,
#  '강매동': 1,
#  '고양동': 16,
#  '관산동': 17,
#  '구산동': 2,
#  '내곡동': 2,
#  '내유동': 14,
#  '대자동': 13,
#  '대장동': 2,
#  '대화동': 46,
#  '덕은동': 4,
#  '덕이동': 44,
#  '도내동': 15,
#  '동산동': 16,
#  '마두동': 19,
#  '문봉동': 9,
#  '백석동': 30,
#  '법곳동': 3,
#  '벽제동': 7,
#  '사리현동': 3,
#  '삼송동': 17,
#  '설문동': 4,
#  '성사동': 14,
#  '성석동': 15,
#  '식사동': 27,
#  '신원동': 12,
#  '오금동': 1,
#  '용두동': 3,
#  '원당동': 1,
#  '원흥동': 13,
#  '일산동': 39,
#  '장항동': 37,
#  '정발산동': 14,
#  '주교동': 17,
#  '주엽동': 23,
#  '중산동': 23,
#  '지영동': 4,
#  '지축동': 4,
#  '탄현동': 29,
#  '토당동': 14,
#  '풍동': 23,
#  '행신동': 37,
#  '향동동': 6,
#  '현천동': 1,
#  '화전동': 4,
#  '화정동': 30}

# %% [markdown]
# # 영화관

# %%
df['상권업종대분류명'].value_counts()
# Out:
# 음식          10916
# 소매          10705
# 생활서비스        6115
# 학문/교육        3055
# 부동산          1597
# 관광/여가/오락      719
# 스포츠           514
# 숙박            126
# Name: 상권업종대분류명, dtype: int64

# %%
play=df[df['상권업종대분류명']=='관광/여가/오락']
movie=play[play['상권업종중분류명']=='연극/영화/극장']
movie['상호명'].value_counts()
# Out:
# 고양필하모닉오케스트라             1
# 뮤직올                     1
# 온아트                     1
# 아트스페이스                  1
# 쏠리데오글로리아성악스튜디오          1
# 한국고미술연구소중국고도자연구소장콜렉션    1
# 더스트프로젝트                 1
# 피오에스연습실                 1
# 유주아트                    1
# 앙상블모닉                   1
# 아람음악당                   1
# 프로콘글로벌                  1
# 에스피엘엔터테인먼트              1
# 극단우물가                   1
# 극단완자무늬                  1
# 퍼펙트                     1
# 대영프로오디오                 1
# 피엔피컨설팅                  1
# 피자오케스트라                 1
# 공간예술                    1
# 한울엔터테인먼트                1
# 바인프로덕션                  1
# 굿프렌즈음악연습실               1
# Name: 상호명, dtype: int64

# %%
df[df['상호명'].str.contains(r'(영화)')]
# Out:
#        Unnamed: 0    상가업소번호            상호명      지점명  상권업종대분류명      상권업종중분류명  \
# 605          9013  25891998        영화공인중개사      NaN       부동산         부동산중개
# 1905        30878  28257445           영화중고      NaN        소매      중고품소매/교환
# 1993        32078  12211909          책과영화휴      NaN     생활서비스        물품기기대여
# 2805        43421  28124731      영화건업더블유앤디      NaN     생활서비스          주택수리
# 4297        68253  25637461           영화마을      NaN     생활서비스        물품기기대여
# 8178       125585  25787559           영화마을    흰돌마을점     생활서비스        물품기기대여
# 9337       143099  12639901  편대장영화식당스타필드고양  스타필드고양점        음식            한식
# 16965      255155  23387090         연극영화학원      NaN     학문/교육     학원-예능취미체육
# 24061      364744   9903138        영화엔지니어링      NaN        소매    가정/주방/인테리어
# 24678      373662  23348736    연극영화뮤지컬입시학원      NaN     학문/교육     학원-보습교습입시
# 25244      383089  26314015           영화부페      NaN        음식            한식
# ...
